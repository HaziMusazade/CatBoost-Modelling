# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("data.csv")
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %%
unique_columns = []
for col in df.columns:
    if(df[col].nunique() <20):
        unique_columns = unique_columns+[col]

# %%
unique_columns.remove('Bankrupt?')
unique_columns
# Out:
# [' Liability-Assets Flag', ' Net Income Flag']

# %%
df.drop(columns=unique_columns).head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df_dummy=pd.get_dummies(df.loc[:, unique_columns])
df_dummy.isnull().sum().sum()
# Out:
# 0

# %%
df_new = pd.concat([df.drop(columns=unique_columns), df_dummy], axis=1)

# %%
df_new.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_new, test_size = 0.3, random_state = 0)

x_train = train.drop('Bankrupt?', axis = 1)
y_train = train['Bankrupt?']

x_test = test.drop('Bankrupt?', axis = 1)
y_test = test['Bankrupt?']

from sklearn.ensemble import BaggingClassifier
from sklearn import tree
model = BaggingClassifier(tree.DecisionTreeClassifier(random_state=1))
model.fit(x_train, y_train)
model.score(x_test, y_test)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((4773, 95), (2046, 95), (4773,), (2046,))

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn import tree
model= BaggingClassifier(tree.DecisionTreeClassifier(random_state=1))
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.9682306940371457

# %%
from sklearn.ensemble import GradientBoostingClassifier
model= GradientBoostingClassifier(learning_rate=0.01, random_state=1)
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.9701857282502444

# %%
import lightgbm as lgb
train_data= lgb.Dataset(x+train, label=y_train)
params = {'learning_rate':0.001}
model= lgb.train(params, train_data, 100)
y_pred=model.predict(x_test)
for i in range(0,185):
    if y_pred[i]>=0.5:
        y_pred[i]=1
else:
    y_pred[i]=0
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-3a61b3012f08> in <module>
# ----> 1 import lightgbm as lgb
#       2 train_data= lgb.Dataset(x+train, label=y_train)
#       3 params = {'learning_rate':0.001}
#       4 model= lgb.train(params, train_data, 100)
#       5 y_pred=model.predict(x_test)
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
from sklearn.model_selection import train_test_split
train, test=train+test_split(df, test_size=0.3, random_state=0)
x_train=train.drop('Bankrupt?', axis=1)
y_train=train['Bankrupt?']
x_test=test.drop('Bankrupt?', axis=1)
y_test=test['Bankrupt?']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b068ab0444d5> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 train, test=train+test_split(df, test_size=0.3, random_state=0)
#       3 x_train=train.drop('Bankrupt?', axis=1)
#       4 y_train=train['Bankrupt?']
#       5 x_test=test.drop('Bankrupt?', axis=1)
#
# NameError: name 'test_split' is not defined

# %%
from catboost import CatBoostClassifier
model=CatBoostClassifier()
categorical_features_indices = np.where(df.types != np.float)[0]
model.fit(x_train, y_train, cat_features=(unique_columns),eval_set=(x+test, y_test))
model.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-d89e11aa53d6> in <module>
# ----> 1 from catboost import CatBoostClassifier
#       2 model=CatBoostClassifier()
#       3 categorical_features_indices = np.where(df.types != np.float)[0]
#       4 model.fit(x_train, y_train, cat_features=(unique_columns),eval_set=(x+test, y_test))
#       5 model.score(x_test,y_test)
#
# ModuleNotFoundError: No module named 'catboost'
